# %%
import pandas as pd
import numpy as np
import seaborn  as sns
import matplotlib.pyplot as plt

# %%
a=[10,20,30,40,50]
b=[1,2,4,5,6]
plt.plot(a,b)

# %%
df=pd.read_csv("C:\\Users\\guriv\\Downloads\\sharma-kohli.csv")

# %%
df
# Out:
#    index  RG Sharma  V Kohli
# 0   2008        404      165
# 1   2009        362      246
# 2   2010        404      307
# 3   2011        372      557
# 4   2012        433      364
# 5   2013        538      639
# 6   2014        390      359
# 7   2015        482      505
# 8   2016        489      973
# 9   2017        333      308

# %%
plt.plot(df["index"], df["V Kohli"], color="#b3903f", linestyle='dashed')
plt.plot(df["index"], df["RG Sharma"], linestyle='dashed')
plt.xlabel("Batsman")
plt.ylabel("runs")
plt.title("analysis")
# Out:
# Text(0.5, 1.0, 'analysis')

# %%
plt.plot(df["index"], df["V Kohli"], color="#b3903f")
plt.plot(df["index"], df["RG Sharma"])
plt.xlabel("Batsman")
plt.ylabel("runs")
plt.title("analysis")
# Out:
# Text(0.5, 1.0, 'analysis')

# %%
plt.plot(df["index"], df["V Kohli"], color="#b3903f", linestyle='dashdot', marker='d')
plt.plot(df["index"], df["RG Sharma"], linewidth="3", marker="*", markersize = "20")
plt.xlabel("Batsman")
plt.ylabel("runs")
plt.title("analysis")
# Out:
# Text(0.5, 1.0, 'analysis')

# %%
plt.plot(df["index"], df["V Kohli"], c="#b3903f", linestyle='dashdot', marker='d', label="virat")
plt.plot(df["index"], df["RG Sharma"], linewidth="3", marker="*", markersize = "20", label="rohit")
plt.xlabel("Batsman")
plt.ylabel("runs")
plt.title("analysis")
plt.legend(loc="upper right")

# %%
plt.plot(df["index"], df["V Kohli"], color="#b3903f", linestyle='dashdot', marker='d')
plt.plot(df["index"], df["RG Sharma"], linewidth="3", marker="*", markersize = "20")
plt.xlabel("Batsman")
plt.ylabel("runs")
plt.title("analysis")
plt.legend(loc="upper right")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
a=[10,20,30,40,50,60]
b=[1,2,4,5,6, 34124]
plt.plot(a,b)
plt.ylim(0,1000)
plt.grid()

# %%
x=np.linspace(-10,10,50)

y=5*x+np.random.randint(1,100,50)
plt.scatter(x,y)

# %%
bat=pd.read_csv("C:\\Users\\guriv\\Downloads\\batter.csv")

# %%
batt= bat.sort_values("runs", ascending=False).head(50)

# %%
plt.scatter(batt["avg"], batt["strike_rate"], marker="*", label="str vs avg")
plt.legend(loc="upper right")

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
plt.scatter(tips["total_bill"], tips["tip"], s=tips["size"]*30, c="green")

# %%
import pandas as pd

# Create a dictionary with the data
data = {
    'Name': ['Alice', 'Bob', 'Carol', 'Dave', 'Eve'],
    'Age': [28, 35, 30, 40, 25],
    'Gender': ['Female', 'Male', 'Female', 'Male', 'Female'],
    'Salary': [70000, 120000, 95000, 110000, 60000],
    'Department': ['HR', 'IT', 'Finance', 'IT', 'HR']
}

# Create a DataFrame from the dictionary
df = pd.DataFrame(data)

df
# Out:
#     Name  Age  Gender  Salary Department
# 0  Alice   28  Female   70000         HR
# 1    Bob   35    Male  120000         IT
# 2  Carol   30  Female   95000    Finance
# 3   Dave   40    Male  110000         IT
# 4    Eve   25  Female   60000         HR

# %%
plt.barh(df["Name"], df["Salary"], color="red")
# Out:
# <BarContainer object of 5 artists>

# %%
ipl=pd.read_csv("C:\\Users\\guriv\\Downloads\\batsman_season_record.csv")

# %%
plt.bar(ipl["batsman"], ipl["2015"], width=0.1)

plt.xticks()
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'AB de Villiers'),
#   Text(1, 0, 'DA Warner'),
#   Text(2, 0, 'MS Dhoni'),
#   Text(3, 0, 'RG Sharma'),
#   Text(4, 0, 'V Kohli')])

# %%
plt.bar(ipl["batsman"], ipl["2016"])
plt.bar(ipl["batsman"], ipl["2017"])
# Out:
# <BarContainer object of 5 artists>

# %%
import pandas as pd

# Create a dictionary with the data
data = {
    'Name': ['Alice', 'Bob', 'Carol', 'Dave', 'Eve'],
    'Age': [28, 35, 30, 40, 25],
    'Gender': ['Female', 'Male', 'Female', 'Male', 'Female'],
    'Salary': [70000, 120000, 95000, 110000, 60000],
    'Department': ['HR', 'IT', 'Finance', 'IT', 'HR']
}

# Create a DataFrame from the dictionary
df = pd.DataFrame(data)

# %%
pd.cut(df["Age"], bins=[1,10,20,30,40], labels=["1-10","10-20","20-30","30-40"])
# Out:
# 0    20-30
# 1    30-40
# 2    20-30
# 3    30-40
# 4    20-30
# Name: Age, dtype: category
# Categories (4, object): ['1-10' < '10-20' < '20-30' < '30-40']

# %%
plt.style.use('dark_background')

# %%
# Out:
#           batsman  2015  2016  2017
# 0  AB de Villiers   513   687   216
# 1       DA Warner   562   848   641
# 2        MS Dhoni   372   284   290
# 3       RG Sharma   482   489   333
# 4         V Kohli   505   973   308

# %%
plt.pie(ipl["2016"], labels=ipl["batsman"], explode = [0.5,0,0,0,0])
# Out:
# ([<matplotlib.patches.Wedge at 0x26e2de33d90>,
# ...
#  [Text(1.2661330506104074, 0.9782162839331513, 'AB de Villiers'),
#   Text(-0.5813124200499217, 0.9338500255906746, 'DA Warner'),
#   Text(-1.0973139266068448, -0.07682542856807445, 'MS Dhoni'),
#   Text(-0.7584052731626211, -0.7967568271681958, 'RG Sharma'),
#   Text(0.656154484808753, -0.8828710506440678, 'V Kohli')])

# %%
plt.savefig("ipl.png")

# %%
pd.MultiIndex.from_tuples([("a",1), ("a",2), ("b",1), ("b",2)])
# Out:
# MultiIndex([('a', 1),
#             ('a', 2),
#             ('b', 1),
#             ('b', 2)],
#            )

# %%
pd.DataFrame([[5,6],[7,8], [9,7], [3,7]], index=pd.MultiIndex.from_tuples([("a",1), ("a",2), ("b",1), ("b",2)]), columns=[["age", "old"], ["bar", "girl"]])
# Out:
#     age  old
#     bar girl
# a 1   5    6
#   2   7    8
# b 1   9    7
#   2   3    7

# %%
iris=sns.load_dataset("iris")
iris["species"].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
plt.figure(figsize=(15,7))
plt.scatter(iris["sepal_length"], iris["petal_length"], c=iris["species"], cmap="jet" )
plt.colorbar()

# %%
iris["species"]=iris["species"].replace({"setosa":1, "virginica":2, "versicolor":3})
# Out:
# C:\Users\guriv\AppData\Local\Temp\ipykernel_9496\2382583247.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   iris["species"]=iris["species"].replace({"setosa":1, "virginica":2, "versicolor":3})

# %%
plt.style.use("ggplot")

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0             5.1          3.5           1.4          0.2        1
# 1             4.9          3.0           1.4          0.2        1
# 2             4.7          3.2           1.3          0.2        1
# 3             4.6          3.1           1.5          0.2        1
# 4             5.0          3.6           1.4          0.2        1
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 5 columns]

# %%
bat=pd.read_csv("C:\\Users\\guriv\\Downloads\\batter (1).csv")

# %%
bat
# Out:
#              batter  runs        avg  strike_rate
# 0           V Kohli  6634  36.251366   125.977972
# 1          S Dhawan  6244  34.882682   122.840842
# 2         DA Warner  5883  41.429577   136.401577
# 3         RG Sharma  5881  30.314433   126.964594
# 4          SK Raina  5536  32.374269   132.535312
# ..              ...   ...        ...          ...
# 600         C Nanda     0   0.000000     0.000000
# 601      Akash Deep     0   0.000000     0.000000
# 602         S Ladda     0   0.000000     0.000000
# 603  V Pratap Singh     0   0.000000     0.000000
# 604    S Lamichhane     0   0.000000     0.000000
#
# [605 rows x 4 columns]

# %%
sbat=bat.head(100).sample(25, random_state=1)

# %%
plt.figure(figsize=(15,10))
plt.scatter(sbat["avg"], sbat["strike_rate"], s=sbat["runs"])
for j in range(sbat.shape[0]):
    plt.text(sbat.iloc[j]["avg"], sbat.iloc[j]["strike_rate"], sbat.iloc[j]["batter"])
plt.axhline(120, c="red")

# %%
plt.subplots()
# Out:
#              batter  runs        avg  strike_rate
# 0           V Kohli  6634  36.251366   125.977972
# 1          S Dhawan  6244  34.882682   122.840842
# 2         DA Warner  5883  41.429577   136.401577
# 3         RG Sharma  5881  30.314433   126.964594
# 4          SK Raina  5536  32.374269   132.535312
# ..              ...   ...        ...          ...
# 600         C Nanda     0   0.000000     0.000000
# 601      Akash Deep     0   0.000000     0.000000
# 602         S Ladda     0   0.000000     0.000000
# 603  V Pratap Singh     0   0.000000     0.000000
# 604    S Lamichhane     0   0.000000     0.000000
#
# [605 rows x 4 columns]

# %%
plt.figure(figsize=(25,20))
plt.subplots(3,3)
plt.subplot(3,3,1)
plt.scatter(bat["avg"], bat["strike_rate"])
plt.subplot(3,3,2)
plt.scatter(bat["avg"], bat["runs"])

# %%
fig ,ax=plt.subplots(2,2)
ax[0,0].scatter(bat["runs"], bat["avg"])

# %%
runs = [500, 600, 700, 300]
avg = [50, 75, 60, 25]
strike_rate = [80, 85, 90, 45]

a=plt.subplot(projection = "3d")

a.scatter3D(runs,avg,strike_rate, c="green")

a.plot3D(runs,avg,strike_rate)

# %%
x=np.linspace(-10,10,100)

x
# Out:
# array([-10.        ,  -9.7979798 ,  -9.5959596 ,  -9.39393939,
#         -9.19191919,  -8.98989899,  -8.78787879,  -8.58585859,
#         -8.38383838,  -8.18181818,  -7.97979798,  -7.77777778,
#         -7.57575758,  -7.37373737,  -7.17171717,  -6.96969697,
#         -6.76767677,  -6.56565657,  -6.36363636,  -6.16161616,
#         -5.95959596,  -5.75757576,  -5.55555556,  -5.35353535,
#         -5.15151515,  -4.94949495,  -4.74747475,  -4.54545455,
#         -4.34343434,  -4.14141414,  -3.93939394,  -3.73737374,
#         -3.53535354,  -3.33333333,  -3.13131313,  -2.92929293,
#         -2.72727273,  -2.52525253,  -2.32323232,  -2.12121212,
#         -1.91919192,  -1.71717172,  -1.51515152,  -1.31313131,
#         -1.11111111,  -0.90909091,  -0.70707071,  -0.50505051,
#         -0.3030303 ,  -0.1010101 ,   0.1010101 ,   0.3030303 ,
#          0.50505051,   0.70707071,   0.90909091,   1.11111111,
#          1.31313131,   1.51515152,   1.71717172,   1.91919192,
# ...

# %%
y=np.linspace(-10,10,100)
y
# Out:
# array([-10.        ,  -9.7979798 ,  -9.5959596 ,  -9.39393939,
#         -9.19191919,  -8.98989899,  -8.78787879,  -8.58585859,
#         -8.38383838,  -8.18181818,  -7.97979798,  -7.77777778,
#         -7.57575758,  -7.37373737,  -7.17171717,  -6.96969697,
#         -6.76767677,  -6.56565657,  -6.36363636,  -6.16161616,
#         -5.95959596,  -5.75757576,  -5.55555556,  -5.35353535,
#         -5.15151515,  -4.94949495,  -4.74747475,  -4.54545455,
#         -4.34343434,  -4.14141414,  -3.93939394,  -3.73737374,
#         -3.53535354,  -3.33333333,  -3.13131313,  -2.92929293,
#         -2.72727273,  -2.52525253,  -2.32323232,  -2.12121212,
#         -1.91919192,  -1.71717172,  -1.51515152,  -1.31313131,
#         -1.11111111,  -0.90909091,  -0.70707071,  -0.50505051,
#         -0.3030303 ,  -0.1010101 ,   0.1010101 ,   0.3030303 ,
#          0.50505051,   0.70707071,   0.90909091,   1.11111111,
#          1.31313131,   1.51515152,   1.71717172,   1.91919192,
# ...

# %%
xx, yy=np.meshgrid(x,y)
xx
# Out:
# array([[-10.       ,  -9.7979798,  -9.5959596, ...,   9.5959596,
#           9.7979798,  10.       ],
#        [-10.       ,  -9.7979798,  -9.5959596, ...,   9.5959596,
#           9.7979798,  10.       ],
#        [-10.       ,  -9.7979798,  -9.5959596, ...,   9.5959596,
#           9.7979798,  10.       ],
#        ...,
#        [-10.       ,  -9.7979798,  -9.5959596, ...,   9.5959596,
#           9.7979798,  10.       ],
#        [-10.       ,  -9.7979798,  -9.5959596, ...,   9.5959596,
#           9.7979798,  10.       ],
#        [-10.       ,  -9.7979798,  -9.5959596, ...,   9.5959596,
#           9.7979798,  10.       ]])

# %%
yy
# Out:
# array([[-10.       , -10.       , -10.       , ..., -10.       ,
#         -10.       , -10.       ],
#        [ -9.7979798,  -9.7979798,  -9.7979798, ...,  -9.7979798,
#          -9.7979798,  -9.7979798],
#        [ -9.5959596,  -9.5959596,  -9.5959596, ...,  -9.5959596,
#          -9.5959596,  -9.5959596],
#        ...,
#        [  9.5959596,   9.5959596,   9.5959596, ...,   9.5959596,
#           9.5959596,   9.5959596],
#        [  9.7979798,   9.7979798,   9.7979798, ...,   9.7979798,
#           9.7979798,   9.7979798],
#        [ 10.       ,  10.       ,  10.       , ...,  10.       ,
#          10.       ,  10.       ]])

# %%
z=xx**2+yy**2

# %%
plt.figure(figsize=(15,10))
ax=plt.subplot(projection = "3d")
b=ax.plot_surface(xx,yy,z, -++cmap="viridis")
plt.colorbar(b)

# %%
plt.contourf(z)

# %%
df=sns.load_dataset("tips")

# %%
sns.heatmap()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[273], line 1
# ----> 1 sns.heatmap(df["sex"], df["smoker"])
#
# TypeError: heatmap() takes 1 positional argument but 2 were given

# %%
df.select_dtypes("number").corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
plt.imshow(df.select_dtypes("number").corr())
plt.grid()
plt.colorbar()

# %%
df.plot(kind="scatter", x="total_bill", y="tip", marker="+")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
df.pivot_table(index="sex", columns="smoker", values=["tip", "total_bill"], aggfunc={"tip":"mean", "total_bill":"sum"})
# Out:
# C:\Users\guriv\AppData\Local\Temp\ipykernel_9496\1776911854.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   df.pivot_table(index="sex", columns="smoker", values=["tip", "total_bill"], aggfunc={"tip":"mean", "total_bill":"sum"})
#              tip           total_bill
# smoker       Yes        No        Yes       No
# sex
# Male    3.051167  3.113402    1337.07  1919.75
# Female  2.931515  2.773519     593.27   977.68

# %%
sns.relplot(tips,kind = "scatter",  x="total_bill", y="tip",col="smoker")
# Out:
# C:\Users\guriv\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.displot(tips ,x= df["tip"], col="sex")
# Out:
# C:\Users\guriv\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\guriv\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1057: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_data = data.groupby(
# C:\Users\guriv\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
sns.rugplot(data=tips, x="tip")
# Out:
# C:\Users\guriv\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='tip'>

# %%
tips.iloc[:,[2,5]]
# Out:
#         sex    time
# 0    Female  Dinner
# 1      Male  Dinner
# 2      Male  Dinner
# 3      Male  Dinner
# 4    Female  Dinner
# ..      ...     ...
# 239    Male  Dinner
# 240  Female  Dinner
# 241    Male  Dinner
# 242    Male  Dinner
# 243  Female  Dinner
#
# [244 rows x 2 columns]

# %%
sns.catplot(tips, x="time", y="tip", kind="strip")
# Out:
# C:\Users\guriv\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\guriv\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\guriv\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\guriv\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
# ...

# %%
sns.catplot(tips, x="time", y="tip", kind="swarm")
# Out:
# C:\Users\guriv\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\guriv\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\guriv\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\guriv\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
# ...

# %%
sns.displot(tips, x="tip", kind="kde", col="time")
# Out:
# C:\Users\guriv\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\guriv\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1057: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_data = data.groupby(
# C:\Users\guriv\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
sns.lmplot(data=tips, x="total_bill", y="tip")
# Out:
# C:\Users\guriv\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(tips, hue="sex")
# Out:
# C:\Users\guriv\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\guriv\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1057: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_data = data.groupby(
# C:\Users\guriv\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
tips.select_dtypes("number")
# Out:
#      total_bill   tip  size
# 0         16.99  1.01     2
# 1         10.34  1.66     3
# 2         21.01  3.50     3
# 3         23.68  3.31     2
# 4         24.59  3.61     4
# ..          ...   ...   ...
# 239       29.03  5.92     3
# 240       27.18  2.00     2
# 241       22.67  2.00     2
# 242       17.82  1.75     2
# 243       18.78  3.00     2
#
# [244 rows x 3 columns]

# %%
sns.lineplot(tips,x= "total_bill", y="tip")
# Out:
# C:\Users\guriv\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\guriv\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='total_bill', ylabel='tip'>
